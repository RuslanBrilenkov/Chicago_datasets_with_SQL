# %%
# Import pandas library
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # There are two ways we can access the data.
#
# 1. Download the data as .csv file and rad from the local repository.
# 2. Provide a link to the data set.
#
# ### let's show both ways

# %% [markdown]
# # First method - having data set locally

# %%
# Read the local file (in "./../" directory), and assign it to variable "df" (pandas instance - data frame)
path = "./../"
table_name = "Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012_.csv"

df = pd.read_csv(path+table_name)

# Showing first 5 rows using command "head()"
print("Showing first 5 rows\n")

df.head(5)
# Out:
# Showing first 5 rows
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# ...

# %% [markdown]
# # Second method - given URL

# %%
# Read the online file by the URL, and assign it to variable "df" (pandas instance - data frame)
path_to_online = "https://data.cityofchicago.org/api/views/9xs2-f89t/rows.csv?accessType=DOWNLOAD"

df = pd.read_csv(path_to_online)#, header=None)

# Showing first 5 rows using command "head()"
print("Showing first 5 rows\n")

df.head(5)
# Out:
# Showing first 5 rows
#    School ID                             Name of School  \
# 0     609966        Charles G Hammond Elementary School
# 1     610539            Marvin Camras Elementary School
# 2     609852           Eliza Chappell Elementary School
# 3     609835         Daniel R Cameron Elementary School
# 4     610521  Sir Miles Davis Magnet Elementary Academy
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES         2819 W 21st Pl   Chicago    IL
# 1                                 ES       3000 N Mango Ave   Chicago    IL
# 2                                 ES      2135 W Foster Ave   Chicago    IL
# 3                                 ES  1234 N Monticello Ave   Chicago    IL
# 4                                 ES      6730 S Paulina St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60623  (773) 535-4580
# 1     60634  (773) 534-2960
# 2     60625  (773) 534-2390
# ...

# %% [markdown]
# ## Some data sets might be quite large (such like data of Chicago crimes in this project ~ 1.5GB). Thus, it might be easier to access it using the second method from above.

# %% [markdown]
# -----

# %% [markdown]
# ---
#
# # Now, we can get statistical summary of every column

# %%
df.describe()
# Out:
#            School ID      ZIP Code  Safety Score  Environment Score  \
# count     566.000000    566.000000    513.000000         513.000000
# mean   609681.791519  60629.727915     49.504873          47.766082
# std      8831.060946     20.248024     20.110837          16.215584
# min    400018.000000  60605.000000      1.000000           1.000000
# 25%    609873.250000  60618.000000     35.000000          37.000000
# 50%    610052.500000  60625.000000     48.000000          47.000000
# 75%    610212.750000  60639.000000     61.000000          58.000000
# max    610544.000000  60827.000000     99.000000          99.000000
#
#        Instruction Score  Average Student Attendance  \
# count         513.000000                  565.000000
# mean           48.288499                   92.313805
# std            17.417176                    5.993053
# min             1.000000                   57.900000
# 25%            37.000000                   91.900000
# ...

# %%
df.describe(include = "all")
# Out:
#             School ID                       Name of School  \
# count      566.000000                                  566
# unique            NaN                                  566
# top               NaN  Claremont Academy Elementary School
# freq              NaN                                    1
# mean    609681.791519                                  NaN
# std       8831.060946                                  NaN
# min     400018.000000                                  NaN
# 25%     609873.250000                                  NaN
# 50%     610052.500000                                  NaN
# 75%     610212.750000                                  NaN
# max     610544.000000                                  NaN
#
#        Elementary, Middle, or High School       Street Address     City State  \
# count                                 566                  566      566   566
# unique                                  3                  550        1     1
# ...

# %% [markdown]
# -------
#
# -------

# %% [markdown]
# # Let us explore a crime data table
#
# ## Reading from the link (skipping this step!)

# %%
# # Read the online file by the URL, and assign it to variable "df" (pandas instance - data frame)
# path_to_online = "https://data.cityofchicago.org/api/views/ijzp-q8t2/rows.csv?accessType=DOWNLOAD"

# df = pd.read_csv(path_to_online)

# # Showing first 5 rows using command "head()"
# print("Showing first 5 rows\n")

# df.head(5)

# %% [markdown]
# ## The data set is very large, so it takes a good while to read it from the link. So, I downloaded it in .csv file - here, reading it from the folder.
#
# ## Also, reading only first 2000 rows - that is not very good as we are cutting down the data set but it is fine for the illustration purposes.

# %%
path = "./../"
filename_crime = "Crimes_-_2001_to_Present.csv"

df = pd.read_csv(path+filename_crime, nrows=2000)#, header=None)

# Showing first 5 rows using command "head()"
print("Showing first 5 rows\n")

df.head(5)
# Out:
# Showing first 5 rows
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11034701    JA366925  01/01/2001 11:00:00 AM       016XX E 86TH PL  1153
# 1  11227287    JB147188  10/08/2017 03:00:00 AM    092XX S RACINE AVE  0281
# 2  11227583    JB147595  03/28/2017 02:00:00 PM       026XX W 79TH ST  0620
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  060XX S EBERHART AVE  0810
# 4  11227634    JB147599  08/26/2017 10:00:00 AM   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# 3                THEFT                            OVER $500
# 4  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %% [markdown]
# ## Let's count the number of crimes recorded in this dataset.

# %%
df['Case Number'].count()
# Out:
# 2000

# %% [markdown]
# # How many crimes resulted in arrest and how many did not
#
# ### (Also, their sum should give the total number of crimes)

# %%
df_arrestFalse = df[df['Arrest']==False]
print("Total number of crimes without arrest = {}".format(df_arrestFalse['Case Number'].count()))

df_arrestTrue = df[df['Arrest']==True]
print("Total number of crimes with arrest = {}".format(df_arrestTrue['Case Number'].count()))

print("Total number of crimes = {}".format(df_arrestFalse['Case Number'].count() + df_arrestTrue['Case Number'].count()) )
# Out:
# Total number of crimes without arrest = 1739
# Total number of crimes with arrest = 261
# Total number of crimes = 2000

# %% [markdown]
# # Which unique types of crimes occured at the HOTEL/MOTEL?

# %%
L = df[df['Location Description']=="HOTEL/MOTEL"]['Primary Type']

print("Number of crimes at HOTEL/MOTEL = {}".format(L.count()) )
print("\nUnique crimes = {}".format( len(L.unique().tolist())) )


print("\nList of uniue crimes at HOTEL/MOTEL: \n{}".format(L.unique().tolist()))
# Out:
# Number of crimes at HOTEL/MOTEL = 11
#
# Unique crimes = 4
#
# List of uniue crimes at HOTEL/MOTEL:
# ['CRIM SEXUAL ASSAULT', 'THEFT', 'BATTERY', 'SEX OFFENSE']

# %% [markdown]
# # Another question we can ask: what is the "most popular" time for crimes from this table data?

# %%
dates = df['Date']

# If you want to convert the time from string to date-time format, uncomment this block of code
# (Caution: it would take a while to complete because the data set is large!)

# for date in dates:

#     from datetime import datetime

#     # date_time_str = '18/09/19 01:55:19'

#     date_time_obj = datetime.strptime(date, '%m/%d/%Y %H:%M:%S %p')


#     #print("The type of the date is now", type(date_time_obj))
#     #print("The date is", date_time_obj)

# %%
# Alternative way of gettign the time is just selecting corresponding indexes - 11 to 22 in this case
print(dates[0][11:22])
# Out:
# 11:00:00 AM

# %%
print(dates.head())
# Out:
# 0    01/01/2001 11:00:00 AM
# 1    10/08/2017 03:00:00 AM
# 2    03/28/2017 02:00:00 PM
# 3    09/09/2017 08:17:00 PM
# 4    08/26/2017 10:00:00 AM
# Name: Date, dtype: object

# %% [markdown]
# # Let's split the column of date into 3 column of day/month/year, time, and local equivalent (AM/PM) for the ease of visualization

# %%
# for date in df['Date']:

#     from datetime import datetime

#     # date_time_str = '18/09/19 01:55:19'

#     date_time_obj = datetime.strptime(date, '%m/%d/%Y %H:%M:%S %p')


#     #print("The type of the date is now", type(date_time_obj))
#     #print("The date is", date_time_obj)

# %% [markdown]
# ## Let's make a copy of our data set

# %%
 df_dates = df

# %% [markdown]
# ### Changing date time format from string to date time

# %%
df_dates["Date"] = df_dates["Date"].astype("datetime64")

# %%
df_dates.head()
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0  11034701    JA366925 2001-01-01 11:00:00       016XX E 86TH PL  1153
# 1  11227287    JB147188 2017-10-08 03:00:00    092XX S RACINE AVE  0281
# 2  11227583    JB147595 2017-03-28 14:00:00       026XX W 79TH ST  0620
# 3  11227293    JB147230 2017-09-09 20:17:00  060XX S EBERHART AVE  0810
# 4  11227634    JB147599 2017-08-26 10:00:00   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# 3                THEFT                            OVER $500
# 4  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False     False  ...   8.0            45.0        11
# ...

# %% [markdown]
# ## By using .dt we can access the date properties
# ## Let's group the data by hour and plot the distribution of crimes with time

# %%
df_by_hour = df_dates.groupby(df["Date"].dt.hour).count()

df_by_hour
# Out:
#        ID  Case Number  Date  Block  IUCR  Primary Type  Description  \
# Date
# 0     456          456   456    456   456           456          456
# 1      21           21    21     21    21            21           21
# 2      11           11    11     11    11            11           11
# 3       8            8     8      8     8             8            8
# 4       6            6     6      6     6             6            6
# 5       8            8     8      8     8             8            8
# 6      33           33    33     33    33            33           33
# 7      42           42    42     42    42            42           42
# 8     115          115   115    115   115           115          115
# 9     234          234   234    234   234           234          234
# 10     95           95    95     95    95            95           95
# 11     77           77    77     77    77            77           77
# ...

# %% [markdown]
# # Now, as we have all of the times, we can plot them on a figure

# %%
df_by_hour["Arrest"].plot(kind = "bar")

# %% [markdown]
# # Here, we see that the peak of crimes happened at midnight. Then, two other peaks at 9 A.M. and 12 P.M.
